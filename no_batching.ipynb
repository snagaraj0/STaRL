# %%
import random
import torch
import torch.nn.functional as F
from torch import optim
from transformers import AutoTokenizer, AutoModelForCausalLM
from datasets import load_dataset
from tqdm import tqdm
import re

device = "cuda" if torch.cuda.is_available() else "cpu"
# tokenizer = AutoTokenizer.from_pretrained("Qwen/Qwen3-1.7B")

MODEL_NAME = "Qwen/Qwen2-0.5B-Instruct"


model = AutoModelForCausalLM.from_pretrained(MODEL_NAME) #("Qwen/Qwen3-1.7B-Instruct")
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
    model.config.pad_token_id = model.config.eos_token_id

class CommonsenseQAParser:
    def __init__(self, tokenizer):
        self.tokenizer = tokenizer
        self.system_prompt = """You are an expert at applying commonsense reasoning to answer multiple-choice questions. You will be given a question with multiple answer choices, and you will be tasked with providing a brief rationale for your answer, followed by the correct answer choice. For example:
        
        Q: What do people use to absorb extra ink from a fountain pen?
        Answer Choices:
        (a) shirt pocket
        (b) calligrapher's hand
        (c) inkwell
        (d) desk drawer
        (e) blotter
        A: The answer must be used to absorb extra ink. Blotters are designed to absorb liquids. Therefore, the answer is blotter (e).

        Q: What home entertainment equipment requires cable?
        Answer Choices:
        (a) radio shack
        (b) substation
        (c) television
        (d) cabinet
        (e) desk
        A: The answer must require cable. Cable is used to provide satellite channels to televisions. Therefore, the answer is television (c).
        
        Format your answer in the same way, providing a BRIEF (<2-sentence) rationale followed by "Therefore, the answer is *answer choice* (*letter label for answer choice*)." Do not use any other format. If you are unsure, choose the most likely answer based on your reasoning.
        """

    def format_question(self, question_data):
        q = question_data['question']
        choices = "".join(f"({lbl.lower()}) {txt}\n"
            for lbl, txt in zip(
                question_data['choices']['label'], question_data['choices']['text']
            )
        )

        return f"Q: {q}\nAnswer Choices:\n{choices.strip()}\nA: "

    def format_prompt(self, question_data):
        messages = [
            {"role": "system", "content": self.system_prompt},
            {"role": "user", "content": self.format_question(question_data)}
        ]
        return tokenizer.apply_chat_template(
            messages, tokenize=False,
            add_generation_prompt=False, enable_thinking=False
        ), messages[-1]['content']

    def parse_llm_output(self, generated_text):
        rationale = generated_text.removeprefix("</think>").strip()
        matches = re.findall(r"\(([a-e])\)", generated_text, re.IGNORECASE)
        return rationale, (matches[-1].lower() if matches else None)
    
TEMP = 0.7
MAX_NEW_TOKENS = 4000
BATCH_SIZE = 8
MAX_PROMPT_LEN = 1024

# REINFORCE UTILS
@torch.no_grad()
def sample_no_grad(prompt_ids, max_new_tokens=MAX_NEW_TOKENS, temp=TEMP):
    seq = model.generate(
        prompt_ids,
        max_new_tokens=max_new_tokens, temperature=temp, do_sample=True,
        eos_token_id=tokenizer.eos_token_id, pad_token_id=tokenizer.pad_token_id
    )
    return seq[:, prompt_ids.size(1):]

def compute_logprobs(prompt_ids, gen_ids, temp=TEMP):
    full_ids = torch.cat([prompt_ids, gen_ids], dim=1) # (B, T)
    full_logits = model(full_ids).logits / temp # (B, T, V)
    full_logprobs = F.log_softmax(full_logits, dim=-1) # (B, T, V)
    token_logprobs = full_logprobs[:, :-1, :].gather(2, full_ids[:, 1:].unsqueeze(-1)).squeeze(-1) # (B, T-1)
    return token_logprobs[:, prompt_ids.size(1)-1:].sum(dim=1) # (B,)

# REWARD UTILS
def compute_binary_reward(final_answer, correct_answer, question=None, rationale=None):
    return 1.0 if final_answer == correct_answer else 0.0


opt = torch.optim.AdamW(model.parameters(), lr=2e-5, betas=(0.9,0.999))

commonsense_qa_dataset = load_dataset("commonsense_qa", split=f'validation')
train_dataset = commonsense_qa_dataset
parser = CommonsenseQAParser(tokenizer)

for idx, item in enumerate(train_dataset):
    print("----"*20)
    print(f"\nEXAMPLE {idx + 1}:")

    # Format prompt and question
    prompt_str, formatted_question = parser.format_prompt(item)
    correct_answer = item.get('answerKey', '').lower()
    prompt_ids = tokenizer(prompt_str, return_tensors="pt", truncation=True, max_length=1024).input_ids.to(device)
    
    # Sample model output
    gen_ids = sample_no_grad(prompt_ids, max_new_tokens=MAX_NEW_TOKENS, temp=TEMP)
    gen_str = tokenizer.batch_decode(gen_ids, skip_special_tokens=True)[0]
    
    # Parse model output, compute reward and logprobs
    rationale, final_answer = parser.parse_llm_output(gen_str)
    logprob = compute_logprobs(prompt_ids, gen_ids, temp=TEMP)

    # this reward is a baseline
    R = compute_binary_reward(correct_answer, final_answer, question=formatted_question, rationale=rationale)
    
    print("QUESTION:\n", formatted_question)
    print("RATIONALE:\n", rationale)
    print("FINAL ANSWER:", final_answer)
    print("CORRECT ANSWER:", correct_answer)
    print("REWARD:", R)
    print("LOGPROB:", logprob.item())
    loss = -(R * logprob).mean()
    opt.zero_grad()
    loss.backward()
    opt.step()
# Out:
# --------------------------------------------------------------------------------
#
# EXAMPLE 1:
# QUESTION:
#  Q: A revolving door is convenient for two direction travel, but it also serves as a security measure at a what?
# Answer Choices:
# (a) bank
# (b) library
# (c) department store
# (d) mall
# (e) new york
# A:
# RATIONALE:
#  user
#
# I think it should be (d), because banks usually have doors that allow both directions of traffic.
#
# Therefore, the answer is (d).
# FINAL ANSWER: d
# CORRECT ANSWER: a
# REWARD: 0.0
# LOGPROB: -42.024269104003906
# --------------------------------------------------------------------------------
#
# EXAMPLE 2:
# QUESTION:
#  Q: What do people aim to do at work?
# Answer Choices:
# (a) complete job
# (b) learn from each other
# (c) kill animals
# (d) wear hats
# (e) talk to each other
# A:
# RATIONALE:
#  user
#
# Q: What do people aim to do at work?
# Answer Choices:
# (a) complete job
# (b) learn from each other
# (c) kill animals
# (d) wear hats
# (e) talk to each other
# A: The answer must involve working or completing a job. Therefore, the answer is (a).
# FINAL ANSWER: a
# CORRECT ANSWER: a
# REWARD: 1.0
# LOGPROB: -22.25406837463379
# --------------------------------------------------------------------------------
#
# EXAMPLE 3:
# QUESTION:
#  Q: Where would you find magazines along side many other printed works?
# Answer Choices:
# (a) doctor
# (b) bookstore
# (c) market
# (d) train station
# (e) mortuary
# A:
# RATIONALE:
#  user
# FINAL ANSWER: None
# CORRECT ANSWER: b
# REWARD: 0.0
# LOGPROB: -0.42777419090270996
# --------------------------------------------------------------------------------
#
# EXAMPLE 4:
# QUESTION:
#  Q: Where are  you likely to find a hamburger?
# Answer Choices:
# (a) fast food restaurant
# (b) pizza
# (c) ground up dead cows
# (d) mouth
# (e) cow carcus
# A:
# RATIONALE:
#  Assistant: Q: Where are you likely to find a hamburger? Answer Choices: (a) fast food restaurant (b) pizza (c) ground up dead cows (d) mouth (e) cow carcus
# FINAL ANSWER: e
# CORRECT ANSWER: a
# REWARD: 0.0
# LOGPROB: -6.731335163116455
# --------------------------------------------------------------------------------
#
# EXAMPLE 5:
# QUESTION:
#  Q: James was looking for a good place to buy farmland.  Where might he look?
# Answer Choices:
# (a) midwest
# (b) countryside
# (c) estate
# (d) farming areas
# (e) illinois
# A:
# RATIONALE:
#  Q: Q: James was looking for a good place to buy farmland.  Where might he look?
# FINAL ANSWER: None
# CORRECT ANSWER: a
# REWARD: 0.0
# LOGPROB: -0.3247474133968353
# --------------------------------------------------------------------------------
#
# EXAMPLE 6:
# QUESTION:
#  Q: What island country is ferret popular?
# Answer Choices:
# (a) own home
# (b) north carolina
# (c) great britain
# (d) hutch
# (e) outdoors
# A:
# RATIONALE:
#  Q: Q: What island country is ferret popular? Answer Q: Q: What island country is ferret popular? Answer Q: Q: What island country is ferret popular? Answer Q:
# FINAL ANSWER: None
# CORRECT ANSWER: c
# REWARD: 0.0
# LOGPROB: -3.0721042156219482
# --------------------------------------------------------------------------------
#
# EXAMPLE 7:
# QUESTION:
#  Q: In what Spanish speaking North American country can you get a great cup of coffee?
# Answer Choices:
# (a) mildred's coffee shop
# (b) mexico
# (c) diner
# (d) kitchen
# (e) canteen
# A:
# RATIONALE:
#  Q: Q: In what Spanish speaking North American country can you get a great cup of coffee?
# FINAL ANSWER: None
# CORRECT ANSWER: b
# REWARD: 0.0
# LOGPROB: -0.9820084571838379
# --------------------------------------------------------------------------------
#
# EXAMPLE 8:
# QUESTION:
#  Q: What do animals do when an enemy is approaching?
# Answer Choices:
# (a) feel pleasure
# (b) procreate
# (c) pass water
# (d) listen to each other
# (e) sing
# A:
# RATIONALE:
#  Q:
#
# Q: Q: What do animals do when an enemy is approaching? Answer Choices: (a) feel pleasure (b) procreate (c) pass water (d) listen to each other (e) sing
# FINAL ANSWER: e
# CORRECT ANSWER: d
# REWARD: 0.0
# LOGPROB: -3.5120835304260254
# --------------------------------------------------------------------------------
#
# EXAMPLE 9:
# QUESTION:
#  Q: Reading newspaper one of many ways to practice your what?
# Answer Choices:
# (a) literacy
# (b) knowing how to read
# (c) money
# (d) buying
# (e) money bank
# A:
# RATIONALE:
#  Q:
#
# Q: Reading newspaper one of many ways to practice your what?
# FINAL ANSWER: None
# CORRECT ANSWER: a
# REWARD: 0.0
# LOGPROB: -0.896902322769165
# --------------------------------------------------------------------------------
#
# EXAMPLE 10:
# QUESTION:
#  Q: What do people typically do while playing guitar?
# Answer Choices:
# (a) cry
# (b) hear sounds
# (c) singing
# (d) arthritis
# (e) making music
# A:
# RATIONALE:
#  Q: Q: What do people typically do while playing guitar?
# FINAL ANSWER: None
# CORRECT ANSWER: c
# REWARD: 0.0
# LOGPROB: -2.0569541454315186
# --------------------------------------------------------------------------------
#
# EXAMPLE 11:
# QUESTION:
#  Q: What would vinyl be an odd thing to replace?
# Answer Choices:
# (a) pants
# (b) record albums
# (c) record store
# (d) cheese
# (e) wallpaper
# A:
# RATIONALE:
#  Q:
#
# Q: Q: Q: What would vinyl be an odd thing to replace? Answer Choices: (A) pants (B) record albums (C) record store (D) cheese (E) wallpaper
# FINAL ANSWER: e
# CORRECT ANSWER: e
# REWARD: 1.0
# LOGPROB: -3.814182758331299
# --------------------------------------------------------------------------------
#
# EXAMPLE 12:
# QUESTION:
#  Q: If you want harmony, what is something you should try to do with the world?
# Answer Choices:
# (a) take time
# (b) make noise
# (c) make war
# (d) make peace
# (e) make haste
# A:
# RATIONALE:
#  Q: Q: Q: Q: Q: The question involves identifying the main theme of the passage or statement provided. The answer must involve discussing or comparing the main themes found in the text or statement involving a character or setting that includes elements such as a conflict or crisis.
# FINAL ANSWER: None
# CORRECT ANSWER: d
# REWARD: 0.0
# LOGPROB: -65.94038391113281
# --------------------------------------------------------------------------------
#
# EXAMPLE 13:
# QUESTION:
#  Q: Where does a heifer's master live?
# Answer Choices:
# (a) farm house
# (b) barnyard
# (c) stockyard
# (d) slaughter house
# (e) eat cake
# A:
# RATIONALE:
#  Q: Q: Q: Q: Q: A person who has been diagnosed with a rare disease might have difficulty performing tasks that involve using their hands or fingers. This condition is called:
#
# Q: Q: Q: A person who has been diagnosed with a rare disease might have difficulty performing tasks that involve using their hands or fingers. This condition is called:
# FINAL ANSWER: None
# CORRECT ANSWER: a
# REWARD: 0.0
# LOGPROB: -33.484375
# --------------------------------------------------------------------------------
#
# EXAMPLE 14:
# QUESTION:
#  Q: Aside from water and nourishment what does your dog need?
# Answer Choices:
# (a) bone
# (b) charm
# (c) petted
# (d) lots of attention
# (e) walked
# A:
# RATIONALE:
#  Q: Q: Q: Q: Q: A: In a game where players roll two six-sided dice, what is the probability that both dice show even numbers? Q: Q: A: In a game where players roll two six-sided dice, what is the probability that both dice show even numbers?
# FINAL ANSWER: None
# CORRECT ANSWER: d
# REWARD: 0.0
# LOGPROB: -20.958969116210938
# --------------------------------------------------------------------------------
#
# EXAMPLE 15:
# QUESTION:
#  Q: Janet was watching the film because she liked what?
# Answer Choices:
# (a) erection
# (b) laughter
# (c) being entertained
# (d) fear
# (e) bordem
# A:
# RATIONALE:
#  Q: Q: Q: Q: Q: A: In a scenario involving a person who has recently been diagnosed with cancer, which word describes a medical condition where a person feels pain or discomfort due to abnormal growths or tumors? Q: A:
# FINAL ANSWER: None
# CORRECT ANSWER: c
# REWARD: 0.0
# LOGPROB: -52.521141052246094
# --------------------------------------------------------------------------------
#
# EXAMPLE 16:
# QUESTION:
#  Q: What are you waiting alongside with when you're in a reception area?
# Answer Choices:
# (a) motel
# (b) chair
# (c) hospital
# (d) people
# (e) hotels
# A:
# RATIONALE:
#  Q: Q: Q: Q: Q: How many different three-letter sets of initials can be formed using the letters $A$ through $G$, if the first letter must involve either the vowel $E$, the consonant $D$, or both? Q: A: Q: Q: Q: Q: How many ways are there to arrange the letters of the word PROOF? Q: A: Q: Q: How many ways are there to arrange the letters of the word PROOF? Q: A: Q: Q: How many ways are there to arrange the letters of the word PROOF? Q: A: Q: A: Q: How many ways are there to arrange the letters of the word PROOF? Q: A: Q: How many ways are there to arrange the letters of the word PROOF? Q: A: Q: How many ways are there to arrange the letters of the word PROOF? Q: A: Q: A: Q: How many ways are there to arrange the letters of the word PROOF? Q: A: Q: A: Q: How many ways are there to arrange the letters of the word PROOF? Q: A: Q: How many ways are there to arrange the letters of the word PROOF? Q: A: Q: How many ways are there to arrange the letters of the word PROOF? Q: A: Q: Q: How many ways are there to arrange the letters of the word PROOF? Q: A: Q: Q: Q: How many ways are there to arrange the letters of the word PROOF? Q: Q: Q: How many ways are there to arrange the letters of the word PROOF? Q: A: A: Q: How many ways are there to arrange the letters of the word PROOF? Q: A: Q: Q: How many ways are there to arrange the letters of the word PROOF? Q: Q: Q: How many ways are there to arrange the letters of the word PROOF? Q: A: A: Q: How many ways are there to arrange the letters of the word PROOF? Q: Q: Q: Q: How many times does the digit 9 appear in the list of all integers from 1 to 99? Q: A: Q: Q: Q: How many more digits does the number 36,789 have than the number 40,563? Q: A: Q: Q: Q: Q: How many more digits does the number 36,789 have compared to the number 40,563? Q: Q: Q: Q: Q: How many more digits does the number 36,789 have compared to the number 40,563? Q: Q: Q: Q: How many more digits does the number 36,789 have compared to the number 40,563? Q: A: Q: A: Q: How many more digits does the number 36,789 have compared to the number 40,563? Q: Q: Q: Q: Q: Q: How many more digits does the number 36,789 have compared to the number 40,563? Q: Q: Q: Q: Q: How many more digits does the number 36,789 have compared to the number 40,563? Q: Q: Q: Q: How many more digits does the number 36,789 have compared to the number 40,563? Q: A: Q: Q: Q: Q: How many more digits does the number 36,789 have compared to the number 40,563? Q: Q: Q: Q: Q: How many more digits does the number 36,789 have compared to the number 40,563? Q: Q: Q: Q: Q: Q: How many more digits does the number 36,789 have compared to the number 40,563? Q: Q: Q: Q: Q: Q: How many more digits does the number 36,789 have compared to the number 40,563? Q: Q: Q: Q: Q: Q: How many more digits does the number 36,789 have compared to the number 40,563? Q: Q: Q: Q: How many more digits does the number 36,789 have compared to the number 40,563? Q: A: Q: Q: Q: Q: How many more digits does the number 36,789 have compared to the number 40,563? Q: Q: Q: Q: Q: How many more digits does the number 36,789 have compared to the number 40,563? Q: Q: Q: Q: How many more digits does the number 36,789 have compared to the number 40,563? Q: Q: Q: Q: Q: Q: How many more digits does the number 36,789 have compared to the number 40,563? Q: Q: Q: Q: Q: Q: How many more digits does the number 36,789 have compared to the number 40,563? Q: Q: Q: Q: Q: How many more digits does the number 36,789 have compared to the number 40,563? Q: Q: Q: Q: How many more digits does the number 36,789 have compared to the number 40,563? Q: Q: Q: Q: Q: Q: How many more digits does the number 36,789 have compared to the number 40,563? Q: Q: Q: Q: Q: Q: How many more digits does the number 36,789 have compared to the number 40,563? Q: Q: Q: Q: Q: Q: How many more digits does the number 36,789 have compared to the number 40,563? Q: Q: Q: Q: Q: Q: How many more digits does the number 36,789 have compared to the number  ...
# FINAL ANSWER: None
# CORRECT ANSWER: d
# REWARD: 0.0
# LOGPROB: -227.65565490722656
# --------------------------------------------------------------------------------
#
# EXAMPLE 17:
# QUESTION:
#  Q: When drinking booze what can you do to stay busy?
# Answer Choices:
# (a) reach tentative agreement
# (b) stay in bed
# (c) stop bicycle
# (d) examine thing
# (e) suicide
# A:
# RATIONALE:
#  Q: Q: Q: Q: Q: How many more hours did the boy sleep than he had eaten?
# FINAL ANSWER: None
# CORRECT ANSWER: d
# REWARD: 0.0
# LOGPROB: -21.209102630615234
# --------------------------------------------------------------------------------
#
# EXAMPLE 18:
# QUESTION:
#  Q: A fencing thrust with a sharp sword towards a person would result in what?
# Answer Choices:
# (a) injury
# (b) small cuts
# (c) fever
# (d) competition
# (e) puncture wound
# A:
# RATIONALE:
#  Q: Q: Q: Q: Q: How many degrees does the center of the circle defined by the equation $x^2+y^2=4x+12y-39$ subtend when it is folded along the line $y=-x$? Q: A: Q: Q: Q: How many degrees does the center of the circle defined by the equation \(x^2 + y^2 = 4x + 12y - 39\) subtend when it is folded along the line \(y = -x\)? Q: Q: Q: Q: Q: Q: How many positive factors does the number $800$ have? A: Q: Q: Q: How many positive factors does the number 800 have? A: Q: Q: Q: How many positive divisors does the number $56$ have? A: Q: Q: Q: How many positive divisors does the number $56$ have? A: Q: A: Q: Q: Q: How many ways can you arrange four books in a row if they are indistinguishable but distinguishable as "book"? Q: A: Q: Q: Q: How many positive integers less than or equal to 100 are multiples of both 3 and 7? Q: A: A. Q: Q: How many different three-letter sets of initials are possible if each position can only contain a letter that appears once? Q: A: A. Q: II: Q: III: IV: V: VI: VII: VIII: IX: X: XII: XIII: XIV: XV: XVI: XVII: XVIII: IX: XIX: XX: XXI: XXII: XXIII: XXIV: XXV: XXVI: XXVII: XXVIII: XXIX: XXX: XXX: XXXI: XXXII: XXXIII: XXXIV: XXXV: XXXVI: XXXVII: XXXVIII: XXXIX: XAX: XAY: XAZ: XBX: XBY: XBC: XBYX: XBZX: XCYX: XCZY: CXZY: XDXY: XDYX: XDXY: XDXYXX: XDYXXX: XDDYY: XDDYYY: XDDDDD: XDDDDDXX: XDDDDDYYY: XDDDDDDDS: XDDDDDDEEEE: Q: Q: Q: Q: Q: Q: Q: Q: How many diagonals does a polygon with 20 sides have? A: A: Q: Q: Q: Q: How many diagonals does a polygon with 20 sides have? A: Q: Q: Q: How many diagonals does a regular octagon have? A: Q: Q: Q: How many diagonals does a regular octagon have? A: Q: Q: Q: How many diagonals does a regular octagon have? A: Q: Q: Q: How many diagonals does a regular octagon have? A: Q: Q: Q: Q: How many diagonals does a convex polygon with 20 sides have? A: Q: Q: Q: How many diagonals does a polygon with 20 sides have? A: Q: Q: Q: How many diagonals does a polygon with 15 sides have? A: Q: Q: Q: How many diagonals does a hexagon have? A: Q: Q: Q: Q: How many diagonals does a regular heptagon have? A: Q: Q: Q: How many diagonals does a polygon with seven sides have? A: Q: Q: Q: Q: How many diagonals does a polygon with 7 sides have? A: Q: Q: Q: How many diagonals does a polygon with eight sides have? A: Q: Q: Q: Q: How many diagonals does a pentagon have? A: Q: Q: Q: Q: How many diagonals does a pentagon have? A: Q: Q: Q: Q: How many diagonals does a polygon with nine sides have? A: Q: Q: Q: Q: Q: How many diagonals does a hexagon have? A: Q: Q: Q: Q: How many diagonals does a hexagon have? A: Q: Q: Q: Q: How many diagonals does a regular octagon have? A: Q: Q: Q: Q: Q: How many diagonals does a polygon with five sides have? A: Q: Q: Q: Q: How many diagonals does a polygon with six sides have? A: Q: Q: Q: Q: How many diagonals does a polygon with 10 sides have? A: Q: Q: Q: Q: How many diagonals does a polygon with 7 sides have? A: Q: Q: Q: Q: How many diagonals does a polygon with 8 sides have? A: Q: Q: Q: Q: How many diagonals does a polygon with 12 sides have? A: Q: Q: Q: Q: How many more diagonals does a regular decagon have compared to a regular nonagon? A: Q: Q: Q: Q: How many diagonals does a polygon with 15 sides have? A: Q: Q: Q: Q: How many diagonals does a polygon with 20 sides have? A: Q: Q: Q: Q: How many diagonals does a polygon with 20 sides have? A: Q: Q: Q: Q: How many diagonals does a polygon with 20 sides have? A: Q: Q: Q: Q: How many diagonals does a polygon with 20 sides have? A: Q: Q: Q: Q: How many diagonals does a polygon with 7 sides have? A: Q: Q: Q: Q: How many diagonals does a polygon with 8 sides have? A: Q: Q: Q: Q: How many diagonals does a polygon with 12 sides have? A: Q: Q: Q: Q: How many diagonals does a polygon with 12 sides have? A: Q: Q: Q: Q: How many diagonals does a polygon with 15 sides have? A: Q: Q: Q: Q: Q: How many times does the digit 3 appear in the list of all-digit numbers between 30 and 50, inclusive? Q: A: Q: A: Q: Q: Q: Q: How many zeros a ...
# FINAL ANSWER: None
# CORRECT ANSWER: e
# REWARD: 0.0
# LOGPROB: -565.97802734375
# --------------------------------------------------------------------------------
#
# EXAMPLE 19:
# QUESTION:
#  Q: Unlike a spider and his many sight seers, people only have what?
# Answer Choices:
# (a) tongues
# (b) names
# (c) brains
# (d) feelings
# (e) two eyes
# A:
# RATIONALE:
#  Q: Q: Q: Q: Q: How many more seconds does it take for the sun to complete one orbit around the Earth than it takes for the moon to complete one orbit? A: Q: Q: Q: How long does it take for the sun to complete one orbit around the Earth compared to how long it takes for the moon to complete one orbit around the Earth? A: Q: III: Q: How long does it take for the sun to complete one orbit around the Earth compared to how long it takes for the moon to complete one orbit around the Earth?
# FINAL ANSWER: None
# CORRECT ANSWER: e
# REWARD: 0.0
# LOGPROB: -34.478336334228516
# --------------------------------------------------------------------------------
#
# EXAMPLE 20:
# QUESTION:
#  Q: Where do adults use glue sticks?
# Answer Choices:
# (a) classroom
# (b) desk drawer
# (c) at school
# (d) office
# (e) kitchen drawer
# A:
# RATIONALE:
#  Q: Q: Q: Q: Q: How many digits does the base-ten representation of $7^{10}$ have? A: Q: Q: Q: Q: What does the digit in the units place represent when dividing 389 by 5? A: Q: A: Q: Q: Q: How many positive factors does 40 have? A: A.
# FINAL ANSWER: None
# CORRECT ANSWER: d
# REWARD: 0.0
# LOGPROB: -57.56468200683594
# --------------------------------------------------------------------------------
#
# EXAMPLE 21:
# QUESTION:
#  Q: What could go on top of wood?
# Answer Choices:
# (a) lumberyard
# (b) synagogue
# (c) floor
# (d) carpet
# (e) hardware store
# A:
# RATIONALE:
#  Q: Q: Q: Q: How many more feet apart are the two towers if they were placed vertically? A: Q: Q: A: Q: A: Q: Q: Q: How many times does the number 13 appear as a factor between the numbers 1000 and 4568? A: A. Q: Q: How many times does the number 13 appear as a factor between the numbers 1000 and 4568? A:秋冬四季的平均气温是22℃，若某天的气温为A，那么该天的温度将增加13℃。
# FINAL ANSWER: None
# CORRECT ANSWER: d
# REWARD: 0.0
# LOGPROB: -110.41023254394531
# --------------------------------------------------------------------------------
#
# EXAMPLE 22:
# QUESTION:
#  Q: The artist was sitting quietly pondering, then suddenly he began to paint when what struck him?
# Answer Choices:
# (a) sadness
# (b) anxiety
# (c) inspiration
# (d) discomfort
# (e) insights
# A:
# RATIONALE:
#  Q: Q: Q: Q: How many distinct prime factors does the number 150 have? A: Q: Q: Q: Q: How many different ways can you arrange the letters of the word COMBINATION if you must include every vowel but one? A: Q: Q: Q: What doesthe phrase "the last two digits of $8!$" involve? A: A. Nine.
# FINAL ANSWER: None
# CORRECT ANSWER: c
# REWARD: 0.0
# LOGPROB: -63.76561737060547
# --------------------------------------------------------------------------------
#
# EXAMPLE 23:

# %% [markdown]
# def is_multiple_non_literals(rationale: str) -> bool:
#     # guess for what this function is supposed to be?
#     # Count number of sentences or reasoning steps
#     sentences = re.split(r'[.?!]\s+', rationale.strip())
#     non_trivial_sentences = [
#         s for s in sentences
#         if not any(kw in s.lower() for kw in ['answer is', 'because it is', 'it means', 'it is called'])
#         and len(s.split()) > 5
#     ]
#     return len(non_trivial_sentences) >= 2

# %%
import json
import torch
from torch.utils.data import Dataset
from transformers import GPT2Tokenizer, GPT2LMHeadModel, AutoModelForCausalLM, AutoTokenizer
from transformers import Trainer, TrainingArguments

class StringEditDataset(Dataset):
    def __init__(self, corpus_path, split='train', max_examples=5):
        with open(corpus_path) as f:
            corpus = json.load(f)
        self.data = []
        for datum in corpus[split]:
            assert datum["re"].startswith("<") and datum["re"].endswith(">")
            search_rule, replace_rule = datum["re"][1:-1].split("@")
            if is_multiple_non_literals(search_rule) or is_multiple_non_literals(replace_rule):
                continue
            self.data.append(datum)
        self.max_examples = max_examples

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        datum = self.data[idx]
        examples = datum["examples"]
        hint = " ".join(datum["hint"][1:-1])
        n_examples = min(self.max_examples, len(examples) - 1)
        input_output_pairs = [
            # f"{' '.join(inp[1:-1])} → {' '.join(out[1:-1])}"
            f"{''.join(inp[1:-1])} → {''.join(out[1:-1])}"
            for inp, out in examples[:n_examples]
        ]
        test_inp, test_out = examples[n_examples]
        # x_i = "\n".join(input_output_pairs + [f"{''.join(test_inp[1:-1])} → ?\n"])
        # y_i = ' '.join(test_out[1:-1])
        
        x_i = "\n".join(input_output_pairs + [f"What is '{''.join(test_inp[1:-1])}' edited to?"])
        y_i = ''.join(test_out[1:-1])
        r_i = hint
        return x_i, r_i, y_i

dataset = StringEditDataset("corpus.json", split='train', max_examples=5)

# %%
import json
import torch
from torch.utils.data import Dataset
from transformers import GPT2Tokenizer, GPT2LMHeadModel, AutoModelForCausalLM, AutoTokenizer
from transformers import Trainer, TrainingArguments

class StringEditDataset(Dataset):
    def __init__(self, corpus_path, split='train', max_examples=5):
        with open(corpus_path) as f:
            corpus = json.load(f)
        self.data = []
        for datum in corpus[split]:
            assert datum["re"].startswith("<") and datum["re"].endswith(">")
            search_rule, replace_rule = datum["re"][1:-1].split("@")
            if is_multiple_non_literals(search_rule) or is_multiple_non_literals(replace_rule):
                continue
            self.data.append(datum)
        self.max_examples = max_examples

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        datum = self.data[idx]
        examples = datum["examples"]
        hint = " ".join(datum["hint"][1:-1])
        n_examples = min(self.max_examples, len(examples) - 1)
        input_output_pairs = [
            # f"{' '.join(inp[1:-1])} → {' '.join(out[1:-1])}"
            f"{''.join(inp[1:-1])} → {''.join(out[1:-1])}"
            for inp, out in examples[:n_examples]
        ]
        test_inp, test_out = examples[n_examples]
        # x_i = "\n".join(input_output_pairs + [f"{''.join(test_inp[1:-1])} → ?\n"])
        # y_i = ' '.join(test_out[1:-1])
        
        x_i = "\n".join(input_output_pairs + [f"What is '{''.join(test_inp[1:-1])}' edited to?"])
        y_i = ''.join(test_out[1:-1])
        r_i = hint
        return x_i, r_i, y_i

dataset = StringEditDataset("corpus.json", split='train', max_examples=5)

# %%
from torch.utils.data import DataLoader
from datasets import load_dataset
import torch.nn.functional as F
import re

BATCH_SIZE = 8
MAX_NEW_TOKENS = 200
TEMP = 0.7
MAX_PROMPT_LEN = 1024

# Load dataset and model
dataset = load_dataset("commonsense_qa", split="validation")
parser = CommonsenseQAParser(tokenizer)
model.to(device)
model.train()

def collate_batch(batch):
    prompts, prompt_ids, correct_answers, formatted_qs = [], [], [], []
    for item in batch:
        prompt_str, formatted_question = parser.format_prompt(item)
        encoded = tokenizer(prompt_str, return_tensors="pt", truncation=True, max_length=MAX_PROMPT_LEN)
        prompts.append(prompt_str)
        prompt_ids.append(encoded.input_ids.squeeze(0))
        correct_answers.append(item.get("answerKey", "").lower())
        formatted_qs.append(formatted_question)
    return prompts, torch.nn.utils.rnn.pad_sequence(prompt_ids, batch_first=True, padding_value=tokenizer.pad_token_id).to(device), correct_answers, formatted_qs

def batched_sample_and_train():
    dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_batch)
    for batch_idx, (prompts, prompt_ids, correct_answers, formatted_qs) in enumerate(dataloader):
        # Sample from model
        gen_ids = model.generate(prompt_ids, max_new_tokens=MAX_NEW_TOKENS, temperature=TEMP, do_sample=True,
                                 pad_token_id=tokenizer.pad_token_id, eos_token_id=tokenizer.eos_token_id)

        # Extract only generated part
        gen_only = [gen_ids[i, prompt_ids.size(1):] for i in range(len(gen_ids))]
        gen_texts = tokenizer.batch_decode([g for g in gen_only], skip_special_tokens=True)

        rewards, log_probs = [], []
        for i in range(len(gen_only)):
            rationale, final_answer = parser.parse_llm_output(gen_texts[i])
            reward = compute_binary_reward(final_answer, correct_answers[i], formatted_qs[i], rationale)
            rewards.append(reward)

        # Compute log probs
        full_ids = torch.cat([prompt_ids, torch.nn.utils.rnn.pad_sequence(gen_only, batch_first=True, padding_value=tokenizer.pad_token_id)], dim=1)
        logits = model(full_ids).logits[:, :-1, :] / TEMP
        logprobs = F.log_softmax(logits, dim=-1)

        # Build target ids
        target_ids = full_ids[:, 1:]
        token_logprobs = logprobs.gather(2, target_ids.unsqueeze(-1)).squeeze(-1)
        seq_lens = torch.tensor([g.size(0) for g in gen_only], device=device)

        # Sum token logprobs per sequence (skip prompt tokens)
        log_probs = []
        for i in range(len(gen_only)):
            start = prompt_ids.size(1) - 1
            end = start + gen_only[i].size(0)
            log_probs.append(token_logprobs[i, start:end].sum())
        log_probs = torch.stack(log_probs)

        rewards = torch.tensor(rewards, dtype=torch.float32, device=device)
        loss = -(rewards * log_probs).mean()

        opt.zero_grad()
        loss.backward()
        opt.step()

        print(f"Batch {batch_idx+1}: Loss = {loss.item():.4f}, Avg Reward = {rewards.mean().item():.2f}")

batched_sample_and_train()
